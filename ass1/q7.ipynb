# %%
import matplotlib.pyplot as p
s=input("Enter a string of letters").lower()
d={}
for i in s:
    if i not in d:
        d[i]=1
    else:
        d[i]+=1

p.bar(d.keys(),d.values())
p.xlabel("alphabets")
p.ylabel("frequencies")
p.show()
